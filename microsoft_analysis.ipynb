# %% [markdown]
# # Final Project Submission
#
# Please fill out:
# * Student name: Henry Van Gorp
# * Student pace: self paced
# * Scheduled project review date/time: 11/19/2021 3:30pm EST
# * Instructor name: Abhineet Kulkarni
# * Blog post URL: https://henryvangorp.com/blog/learning-data

# %% [markdown]
# ![example](https://raw.githubusercontent.com/learn-co-curriculum/dsc-project-template/template-mvp/images/director_shot.jpeg)

# %% [markdown]
# ## Overview
#
# This project analyzes data from the biggest movie related websites to help Microsoft understand where current oppurtunities lie in the realm of film.  The popular websites of IMDB and Box Office Mojo provided the necessary data to create the analysis.  Analysis of the previously mentioned data shows that the genre sci-fi averages the highest domestic gross while documenteries have the highest average score on IMDB.  Also, the recommendation that movies which have a runtime of 100 to 150 minutes average the highest domestic gross was put foward.  Microsoft is able to utlize the findings and recommendations produced while entering the movie sphere.

# %% [markdown]
# ## Business Problem
#
# Microsoft sees all the big companies creating original video content and they want to get in on the fun. They have decided to create a new movie studio, but they don’t know anything about creating movies. This project explores what types of genres are currently doing the best at the box office with Domestic Gross as well as scoring the highest on IMDB.  Ths project also looks at runtime in comparison to domestic gross.  Utilizing this information, microsoft will be given three business recommendations to utlize as they enter this world.

# %% [markdown]
# ## Data Understanding
#
#
# The data which is being utlized for this project focuses on domestic gross, IMDB score, and runtime.  The data used in the analysis below came from reputable and popular movie based websites (IMDB & Box Office Mojo) which focus on box office revenue, overall movie rating and details of movies (i.e. runtime in mimutes).

# %% [markdown]
# ### Import Packages and Files

# %%
#import packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#import glob to return all filepaths
import glob, os
fpath = 'zippedData/'
os.listdir(fpath)
# Out:
# ['imdb.title.crew.csv.gz',
#  'tmdb.movies.csv.gz',
#  'imdb.title.akas.csv.gz',
#  'imdb.title.ratings.csv.gz',
#  'imdb.name.basics.csv.gz',
#  'rt.reviews.tsv.gz',
#  'imdb.title.basics.csv.gz',
#  'rt.movie_info.tsv.gz',
#  'tn.movie_budgets.csv.gz',
#  'bom.movie_gross.csv.gz',
#  'imdb.title.principals.csv.gz']

# %%
#Adding .gz to the fpath to be looped through
query = fpath+"*.gz"

file_list = glob.glob(query)
file_list
# Out:
# ['zippedData/imdb.title.crew.csv.gz',
#  'zippedData/tmdb.movies.csv.gz',
#  'zippedData/imdb.title.akas.csv.gz',
#  'zippedData/imdb.title.ratings.csv.gz',
#  'zippedData/imdb.name.basics.csv.gz',
#  'zippedData/rt.reviews.tsv.gz',
#  'zippedData/imdb.title.basics.csv.gz',
#  'zippedData/rt.movie_info.tsv.gz',
#  'zippedData/tn.movie_budgets.csv.gz',
#  'zippedData/bom.movie_gross.csv.gz',
#  'zippedData/imdb.title.principals.csv.gz']

# %% [markdown]
# ### File Tables

# %%
#Run a for loop to return the head and tail of each table
tables = {}
for file in file_list:
    print('---'*20)
    file_name = file.replace('zippedData/', '').replace('.','_')
        
    print(file_name)
    
    if '.tsv.gz' in file:
        temp_df =pd.read_csv(file, sep="\t", encoding="latin-1")
    else:
        temp_df = pd.read_csv(file)
    display(temp_df.head(), temp_df.tail())
    
    tables[file_name] = temp_df
# Out:
# ------------------------------------------------------------
# imdb_title_crew_csv_gz
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
#            tconst              directors     writers
# 146139  tt8999974             nm10122357  nm10122357
# 146140  tt9001390              nm6711477   nm6711477
# 146141  tt9001494  nm10123242,nm10123248         NaN
# 146142  tt9004986              nm4993825   nm4993825
# 146143  tt9010172                    NaN   nm8352242
# ------------------------------------------------------------
# tmdb_movies_csv_gz
#    Unnamed: 0            genre_ids     id original_language  \
# ...

# %% [markdown]
# ## Data Preparation
#
# This project utilizes descriptive and predictive analysis.  This provides and overview of how genres have succeeded in the categories of domestic gross and IMDB scoring as well as predicting how a film can benefit from utilizing a range in runtime.

# %% [markdown]
# ### Q1: What Genres Earn the Highest Gross (Domestic)

# %%
#Create variable using the box office mojo dataset
bom_movie_gross = tables['bom_movie_gross_csv_gz'].copy()
bom_movie_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
#Create variable using the IMDB title basics dataset
imdb_title_basics = tables['imdb_title_basics_csv_gz'].copy()
imdb_title_basics
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
#Join the box office mojo and IMDB title basic datasets using 'title' and
# 'primary title'
df = pd.merge(bom_movie_gross, imdb_title_basics, left_on='title', 
    right_on='primary_title')
df
# Out:
#                            title  studio  domestic_gross foreign_gross  year  \
# 0                    Toy Story 3      BV     415000000.0     652000000  2010
# 1                      Inception      WB     292600000.0     535700000  2010
# 2            Shrek Forever After    P/DW     238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse    Sum.     300500000.0     398000000  2010
# 4                     Iron Man 2    Par.     312400000.0     311500000  2010
# ...                          ...     ...             ...           ...   ...
# 3361                    Souvenir  Strand         11400.0           NaN  2018
# 3362                    Souvenir  Strand         11400.0           NaN  2018
# 3363         Beauty and the Dogs   Osci.          8900.0           NaN  2018
# 3364                   The Quake   Magn.          6200.0           NaN  2018
# 3365           An Actor Prepares   Grav.          1700.0           NaN  2018
#
# ...

# %%
#Remove duplicates based on three columns.
df[df.duplicated(keep=False, subset=['title','original_title','domestic_gross'])]
# Out:
#            title  studio  domestic_gross foreign_gross  year     tconst  \
# 14    Robin Hood    Uni.     105300000.0     216400000  2010  tt0955308
# 15    Robin Hood    Uni.     105300000.0     216400000  2010  tt2363363
# 16    Robin Hood    Uni.     105300000.0     216400000  2010  tt4532826
# 17    Robin Hood    Uni.     105300000.0     216400000  2010  tt6858500
# 18    Robin Hood    Uni.     105300000.0     216400000  2010  tt8558276
# ...          ...     ...             ...           ...   ...        ...
# 3357  The Escape     IFC         14000.0           NaN  2018  tt5053302
# 3358  The Escape     IFC         14000.0           NaN  2018  tt6069126
# 3360    Souvenir  Strand         11400.0           NaN  2018  tt2387692
# 3361    Souvenir  Strand         11400.0           NaN  2018  tt2389092
# 3362    Souvenir  Strand         11400.0           NaN  2018  tt3478898
#
#      primary_title original_title  start_year  runtime_minutes  \
# ...

# %%
#Keep the first mention of all duplicates
df = df.drop_duplicates(keep='first', subset=['title','original_title','domestic_gross'])
df[df.duplicated(keep=False, subset=['title','original_title','domestic_gross'])]
# Out:
# Empty DataFrame
# Columns: [title, studio, domestic_gross, foreign_gross, year, tconst, primary_title, original_title, start_year, runtime_minutes, genres]
# Index: []

# %%
df
# Out:
#                            title  studio  domestic_gross foreign_gross  year  \
# 0                    Toy Story 3      BV     415000000.0     652000000  2010
# 1                      Inception      WB     292600000.0     535700000  2010
# 2            Shrek Forever After    P/DW     238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse    Sum.     300500000.0     398000000  2010
# 4                     Iron Man 2    Par.     312400000.0     311500000  2010
# ...                          ...     ...             ...           ...   ...
# 3359             Let Yourself Go    Men.         12200.0           NaN  2018
# 3360                    Souvenir  Strand         11400.0           NaN  2018
# 3363         Beauty and the Dogs   Osci.          8900.0           NaN  2018
# 3364                   The Quake   Magn.          6200.0           NaN  2018
# 3365           An Actor Prepares   Grav.          1700.0           NaN  2018
#
# ...

# %% [markdown]
# ### Q2: What Genres Have the Highest Score on IMDB

# %%
#Create the variable imdb_title_ratings
imdb_title_ratings = tables['imdb_title_ratings_csv_gz'].copy()
imdb_title_ratings
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
#Merge df with imdb title ratings on 'tconst'
df2 = pd.merge(df, imdb_title_ratings, on='tconst')
df2
# Out:
#                            title  studio  domestic_gross foreign_gross  year  \
# 0                    Toy Story 3      BV     415000000.0     652000000  2010
# 1                      Inception      WB     292600000.0     535700000  2010
# 2            Shrek Forever After    P/DW     238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse    Sum.     300500000.0     398000000  2010
# 4                     Iron Man 2    Par.     312400000.0     311500000  2010
# ...                          ...     ...             ...           ...   ...
# 2683             Let Yourself Go    Men.         12200.0           NaN  2018
# 2684                    Souvenir  Strand         11400.0           NaN  2018
# 2685         Beauty and the Dogs   Osci.          8900.0           NaN  2018
# 2686                   The Quake   Magn.          6200.0           NaN  2018
# 2687           An Actor Prepares   Grav.          1700.0           NaN  2018
#
# ...

# %% [markdown]
# ### Q3: What Run Time Has the Highest Rating

# %%
#Create the variable df3
df3 = df2
df3
# Out:
#                            title  studio  domestic_gross foreign_gross  year  \
# 0                    Toy Story 3      BV     415000000.0     652000000  2010
# 1                      Inception      WB     292600000.0     535700000  2010
# 2            Shrek Forever After    P/DW     238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse    Sum.     300500000.0     398000000  2010
# 4                     Iron Man 2    Par.     312400000.0     311500000  2010
# ...                          ...     ...             ...           ...   ...
# 2683             Let Yourself Go    Men.         12200.0           NaN  2018
# 2684                    Souvenir  Strand         11400.0           NaN  2018
# 2685         Beauty and the Dogs   Osci.          8900.0           NaN  2018
# 2686                   The Quake   Magn.          6200.0           NaN  2018
# 2687           An Actor Prepares   Grav.          1700.0           NaN  2018
#
# ...

# %% [markdown]
# ## Data Analysis
# After merging the necessary tables together, the data was in a place where analysis could be begun.  Utilizing pandas, the data was able to get to a place wher visualizations were created with seaborn.

# %% [markdown]
# ### Q1: What Genres Earn the Highest Gross (Domestic)

# %%
#Split the genres column to be able to use grouby
df['new_genres']=df['genres'].str.split(',')
df
# Out:
# <ipython-input-14-729f7a4fb2da>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['new_genres']=df['genres'].str.split(',')
#                            title  studio  domestic_gross foreign_gross  year  \
# 0                    Toy Story 3      BV     415000000.0     652000000  2010
# 1                      Inception      WB     292600000.0     535700000  2010
# 2            Shrek Forever After    P/DW     238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse    Sum.     300500000.0     398000000  2010
# 4                     Iron Man 2    Par.     312400000.0     311500000  2010
# ...                          ...     ...             ...           ...   ...
# ...

# %%
#Utlize explode to duplicate rows to match all genres listed
df_genres = df.explode('new_genres')
df_genres
# Out:
#                     title studio  domestic_gross foreign_gross  year  \
# 0             Toy Story 3     BV     415000000.0     652000000  2010
# 0             Toy Story 3     BV     415000000.0     652000000  2010
# 0             Toy Story 3     BV     415000000.0     652000000  2010
# 1               Inception     WB     292600000.0     535700000  2010
# 1               Inception     WB     292600000.0     535700000  2010
# ...                   ...    ...             ...           ...   ...
# 3363  Beauty and the Dogs  Osci.          8900.0           NaN  2018
# 3364            The Quake  Magn.          6200.0           NaN  2018
# 3364            The Quake  Magn.          6200.0           NaN  2018
# 3364            The Quake  Magn.          6200.0           NaN  2018
# 3365    An Actor Prepares  Grav.          1700.0           NaN  2018
#
#          tconst        primary_title     original_title  start_year  \
# 0     tt0435761          Toy Story 3        Toy Story 3        2010
# ...

# %%
#Found the mean of domestic gross by genre and sorted them in ascending order
genre_mean = df_genres.groupby('new_genres').mean()['domestic_gross']
genre_mean = genre_mean.sort_values(ascending = False)
genre_mean.index
# Out:
# Index(['Sci-Fi', 'Adventure', 'Animation', 'Action', 'Fantasy', 'Family',
#        'Comedy', 'Thriller', 'Sport', 'Western', 'Horror', 'Mystery', 'Crime',
#        'Musical', 'Biography', 'Music', 'Drama', 'Romance', 'History',
#        'Documentary', 'War', 'News'],
#       dtype='object', name='new_genres')

# %%
#Utilizing seasborn, plotted a bar plot
ax = sns.barplot(data=df_genres, x = 'new_genres', y = 'domestic_gross',
                order = genre_mean.index)
ax.set_title('Domestic Gross By Genre', size=30)
ax.set_xlabel("Genres", size=20)
ax.set_ylabel("Avgerage Domestic Gross", size=20)
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45, ha = 'right');

# %% [markdown]
# ### Q2: What Genres Have the Highest Score on IMDB

# %%
#Split the genres column
df2['new_genres']=df2['genres'].str.split(',')
df2
# Out:
#                            title  studio  domestic_gross foreign_gross  year  \
# 0                    Toy Story 3      BV     415000000.0     652000000  2010
# 1                      Inception      WB     292600000.0     535700000  2010
# 2            Shrek Forever After    P/DW     238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse    Sum.     300500000.0     398000000  2010
# 4                     Iron Man 2    Par.     312400000.0     311500000  2010
# ...                          ...     ...             ...           ...   ...
# 2683             Let Yourself Go    Men.         12200.0           NaN  2018
# 2684                    Souvenir  Strand         11400.0           NaN  2018
# 2685         Beauty and the Dogs   Osci.          8900.0           NaN  2018
# 2686                   The Quake   Magn.          6200.0           NaN  2018
# 2687           An Actor Prepares   Grav.          1700.0           NaN  2018
#
# ...

# %%
#Utlize explode to duplicate rows to match all genres listed
df2_genres = df2.explode('new_genres')
df2_genres
# Out:
#                     title studio  domestic_gross foreign_gross  year  \
# 0             Toy Story 3     BV     415000000.0     652000000  2010
# 0             Toy Story 3     BV     415000000.0     652000000  2010
# 0             Toy Story 3     BV     415000000.0     652000000  2010
# 1               Inception     WB     292600000.0     535700000  2010
# 1               Inception     WB     292600000.0     535700000  2010
# ...                   ...    ...             ...           ...   ...
# 2685  Beauty and the Dogs  Osci.          8900.0           NaN  2018
# 2686            The Quake  Magn.          6200.0           NaN  2018
# 2686            The Quake  Magn.          6200.0           NaN  2018
# 2686            The Quake  Magn.          6200.0           NaN  2018
# 2687    An Actor Prepares  Grav.          1700.0           NaN  2018
#
#          tconst        primary_title     original_title  start_year  \
# 0     tt0435761          Toy Story 3        Toy Story 3        2010
# ...

# %%
#Determine the average rating per genre
genre_ratings_mean = df2_genres.groupby('new_genres').mean()['averagerating']
genre_ratings_mean = genre_ratings_mean.sort_values(ascending = False)
genre_ratings_mean.index
# Out:
# Index(['Documentary', 'Biography', 'History', 'Sport', 'War', 'Music',
#        'Western', 'News', 'Animation', 'Drama', 'Crime', 'Sci-Fi', 'Adventure',
#        'Romance', 'Action', 'Mystery', 'Fantasy', 'Comedy', 'Thriller',
#        'Musical', 'Family', 'Horror'],
#       dtype='object', name='new_genres')

# %%
#Graph the average IMDB rating by genre using seaborn
ax = sns.barplot(data=df2_genres, x = 'new_genres', y = 'averagerating',
                order = genre_ratings_mean.index)
ax.set_title('IMDB Rating By Genre', size=25)
ax.set_xlabel("Genres", size=20)
ax.set_ylabel("Avgerage IMDB Rating", size=20)
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45, ha = 'right');

# %% [markdown]
# ### Q3: What Run Time Has the Highest Rating

# %%
#Graph runtime in comparison with domestic gross
ax = sns.regplot(data=df3, x = 'runtime_minutes', y = 'domestic_gross',
                 scatter_kws={'alpha': 0.7}, line_kws={'color': 'black'})
ax.set_title('Domestic Gross By Runtime', size=25)
ax.set_xlabel("Runtime in Minutes", size=20)
ax.set_ylabel("Domestic Gross", size=20)
# Out:
# Text(0, 0.5, 'Domestic Gross')

# %% [markdown]
# ## Evaluation
#
# The work which I have provided above will help with the business problem given.  It will guide in not only the genres which should be prioritized but also one of the most ciritical aspects of a film, the runtime.

# %% [markdown]
# ## Conclusions
#
# This analysis leads to three recommendations on where Micorsoft should focus in the film industry:
#
# - Focus on the top three genres who average the highest domestic gross.  The following genres in order are Sci-Fi, Adventure, and Animation.
# - Regarding how films are rated, it is worth noting that Sci-Fi, even though averaging the highest domestic gross falls in the middle of the pack when it comes to IMDB Score.  Documentaries, Biographies, and History have the highest IMDB Score.
# - Look to create films that average a runtime between 100 to 150 minutes.  These films produce the highest domestic gross.
